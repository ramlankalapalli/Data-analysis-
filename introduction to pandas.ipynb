# %%
import pandas as pd

# %%
series=pd.Series(["BMW","AUDI","FERRAI"])

# %%
series
# Out:
# 0       BMW
# 1      AUDI
# 2    FERRAI
# dtype: object

# %%
colours=pd.Series(["Red","Blue","Orange"])

# %%
colours
# Out:
# 0       Red
# 1      Blue
# 2    Orange
# dtype: object

# %%
car_data=pd.DataFrame({"Car Make": series,"Colours":colours})

# %%
car_data
# Out:
#   Car Make Colours
# 0      BMW     Red
# 1     AUDI    Blue
# 2   FERRAI  Orange

# %%
#Import Data 
car_sales=pd.read_csv("carsales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("exported_car_sales.csv",index=False)

# %%
exported_car_sales= pd.read_csv("exported_car_sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
#    Describe Data

# %%
#Attributes
car_sales.dtypes

#Functions
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns=car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
 car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
car_sales["Odometer (KM)"].sum()
# Out:
# 786014

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### Viewing and selecting Data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(8)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00

# %%
car_sales.tail(4)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
#.loc & .iloc
#Python list and data frames in series start from zero.
animals=pd.Series(["cats","dogs","snakes","bulls","cows"],index=[0,1,4,6,8])
animals
# Out:
# 0      cats
# 1      dogs
# 4    snakes
# 6     bulls
# 8      cows
# dtype: object

# %%
#we can consider as short location or directly call throught index number
#loc refers to is the index numbers.
animals.loc[8]
# Out:
# 'cows'

# %%
#its start count with zero 
animals.iloc[3]
# Out:
# 'bulls'

# %%
animals
# Out:
# 0      cats
# 1      dogs
# 4    snakes
# 6     bulls
# 8      cows
# dtype: object

# %%
car_sales.loc[5]
# Out:
# Make                Toyota
# Colour               Green
# Odometer (KM)        99213
# Doors                    4
# Price            $4,500.00
# Name: 5, dtype: object

# %%
#iloc refers to position to index in python and data frame starts with zero.
animals.iloc[2]
# Out:
# 'snakes'

# %%
#loc refers to index
car_sales.loc[3]
#iloc refers to position
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      cats
# 1      dogs
# 4    snakes
# 6     bulls
# 8      cows
# dtype: object

# %%
animals.iloc[:3]
# Out:
# 0      cats
# 1      dogs
# 4    snakes
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.head(4)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
#car_sales["Make"] 

car_sales.Make     #this 2 lines are exact do same
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
#if we have dot notation get an error.
car_sales.Odometer (KM)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-cffc0afb7077> in <module>
# ----> 1 car_sales.Odometer (KM)
#
# ~\sample_project1\env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Odometer'

# %%
#THIS CONDITION IS BOOLEAN INDEXING
car_sales[car_sales['Make']=="Honda"]
# Out:
#     Make Colour  Odometer (KM)  Doors      Price
# 1  Honda    Red          87899      4  $5,000.00
# 6  Honda   Blue          45698      4  $7,500.00
# 7  Honda   Blue          54738      4  $7,000.00

# %%
car_sales[car_sales['Odometer (KM)']>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
#Crosstab is comparing two columns 
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
#Groupby means more than one column compare we use this
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].plot()

# %%
car_sales["Odometer (KM)"].hist()

# %%
car_sales["Price"].dtype
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"]=car_sales["Price"].str.replace('[\$\,\.]','').astype(int)

# %%
#car_sales["Price"].plot()
car_sales["Price"].hist()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %% [markdown]
# ## Mainpulating Data

# %%
car_sales["Make"].str.upper()
#car_sales["Make"].str.lower()
# Out:
# 0    TOYOTA
# 1     HONDA
# 2    TOYOTA
# 3       BMW
# 4    NISSAN
# 5    TOYOTA
# 6     HONDA
# 7     HONDA
# 8    TOYOTA
# 9    NISSAN
# Name: Make, dtype: object

# %%
car_sales['Make']=car_sales['Make'].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  white         150043      4   400000
# 1   honda    red          87899      4   500000
# 2  toyota   blue          32549      3   700000
# 3     bmw  black          11179      5  2200000
# 4  nissan  white         213095      4   350000
# 5  toyota  green          99213      4   450000
# 6   honda   blue          45698      4   750000
# 7   honda   blue          54738      4   700000
# 8  toyota  white          60000      4   625000
# 9  nissan  white          31600      4   970000

# %%
car_sales_missing=pd.read_csv("car_sales_missing.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
#car_sales_missing["Odometer"]=car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing["Doors"].fillna(car_sales_missing["Doors"].mean(),inplace=True) #inplace is without resiging the values automatically inserted in original data frame.

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    4.0      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing=pd.read_csv("car_sales_missing.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped=car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car_sales_missing_dropped.csv")
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
#Column for series
seats_columns=pd.Series([5,5,5,5,5])
#New column called seats
car_sales["Seats"]=seats_columns
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  white         150043      4   400000    5.0
# 1   honda    red          87899      4   500000    5.0
# 2  toyota   blue          32549      3   700000    5.0
# 3     bmw  black          11179      5  2200000    5.0
# 4  nissan  white         213095      4   350000    5.0
# 5  toyota  green          99213      4   450000    NaN
# 6   honda   blue          45698      4   750000    NaN
# 7   honda   blue          54738      4   700000    NaN
# 8  toyota  white          60000      4   625000    NaN
# 9  nissan  white          31600      4   970000    NaN

# %%
car_sales["Seats"].fillna(5,inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  white         150043      4   400000    5.0
# 1   honda    red          87899      4   500000    5.0
# 2  toyota   blue          32549      3   700000    5.0
# 3     bmw  black          11179      5  2200000    5.0
# 4  nissan  white         213095      4   350000    5.0
# 5  toyota  green          99213      4   450000    6.0
# 6   honda   blue          45698      4   750000    6.0
# 7   honda   blue          54738      4   700000    6.0
# 8  toyota  white          60000      4   625000    6.0
# 9  nissan  white          31600      4   970000    6.0

# %%
#Column for python list
fuel_economy=[7.5,5.6,8.5,6.7,9.3,2.1,3.0,8.0,5.0,8.0]
car_sales["fuel per 100k"]=fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  fuel per 100k
# 0  toyota  white         150043      4   400000    5.0            7.5
# 1   honda    red          87899      4   500000    5.0            5.6
# 2  toyota   blue          32549      3   700000    5.0            8.5
# 3     bmw  black          11179      5  2200000    5.0            6.7
# 4  nissan  white         213095      4   350000    5.0            9.3
# 5  toyota  green          99213      4   450000    6.0            2.1
# 6   honda   blue          45698      4   750000    6.0            3.0
# 7   honda   blue          54738      4   700000    6.0            8.0
# 8  toyota  white          60000      4   625000    6.0            5.0
# 9  nissan  white          31600      4   970000    6.0            8.0

# %%
car_sales["Total fuel used(L)"]=car_sales["Odometer (KM)"]/100 * car_sales["fuel per 100k"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  fuel per 100k  \
# 0  toyota  white         150043      4   400000    5.0            7.5
# 1   honda    red          87899      4   500000    5.0            5.6
# 2  toyota   blue          32549      3   700000    5.0            8.5
# 3     bmw  black          11179      5  2200000    5.0            6.7
# 4  nissan  white         213095      4   350000    5.0            9.3
# 5  toyota  green          99213      4   450000    6.0            2.1
# 6   honda   blue          45698      4   750000    6.0            3.0
# 7   honda   blue          54738      4   700000    6.0            8.0
# 8  toyota  white          60000      4   625000    6.0            5.0
# 9  nissan  white          31600      4   970000    6.0            8.0
#
#    Total fuel used(L)  Number of wheels
# 0           11253.225                 4
# 1            4922.344                 4
# 2            2766.665                 4
# ...

# %%
car_sales["Number of wheels"]=4
car_sales
car_sales=car_sales.drop("Number of wheel", axis=1)

# %%
car_sales["Passed for saftey"]=True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  fuel per 100k  \
# 0  toyota  white         150043      4   400000    5.0            7.5
# 1   honda    red          87899      4   500000    5.0            5.6
# 2  toyota   blue          32549      3   700000    5.0            8.5
# 3     bmw  black          11179      5  2200000    5.0            6.7
# 4  nissan  white         213095      4   350000    5.0            9.3
# 5  toyota  green          99213      4   450000    6.0            2.1
# 6   honda   blue          45698      4   750000    6.0            3.0
# 7   honda   blue          54738      4   700000    6.0            8.0
# 8  toyota  white          60000      4   625000    6.0            5.0
# 9  nissan  white          31600      4   970000    6.0            8.0
#
#    Total fuel used(L)  Number of wheels  Passed for saftey
# 0           11253.225                 4               True
# 1            4922.344                 4               True
# ...

# %%
car_sales.dtypes
# Out:
# Make                   object
# Colour                 object
# Odometer (KM)           int64
# Doors                   int64
# Price                   int32
# Seats                 float64
# fuel per 100k         float64
# Total fuel used(L)    float64
# Number of wheels        int64
# Passed for saftey        bool
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-bcc54e08e53f> in <module>
# ----> 1 car_sales=car_sales.drop("Total fuel used", axis=1)
#
# ~\sample_project1\env\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~\sample_project1\env\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  fuel per 100k  \
# 0  toyota  white         150043      4   400000    5.0            7.5
# 1   honda    red          87899      4   500000    5.0            5.6
# 2  toyota   blue          32549      3   700000    5.0            8.5
# 3     bmw  black          11179      5  2200000    5.0            6.7
# 4  nissan  white         213095      4   350000    5.0            9.3
# 5  toyota  green          99213      4   450000    6.0            2.1
# 6   honda   blue          45698      4   750000    6.0            3.0
# 7   honda   blue          54738      4   700000    6.0            8.0
# 8  toyota  white          60000      4   625000    6.0            5.0
# 9  nissan  white          31600      4   970000    6.0            8.0
#
#    Total fuel used(L)  Number of wheels  Passed for saftey  fluids   Types
# 0           11253.225                 4               True  Dissel  Dissel
# ...

# %%
car_sales["Types"]=["Dissel","Petrol","Dissel","Petrol","Dissel","Petrol","Dissel","Petrol","Dissel","Petrol"]
car_sales["Types"]
car_sales=car_sales.drop("fluids", axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  fuel per 100k  \
# 0  toyota  white         150043      4   400000    5.0            7.5
# 1   honda    red          87899      4   500000    5.0            5.6
# 2  toyota   blue          32549      3   700000    5.0            8.5
# 3     bmw  black          11179      5  2200000    5.0            6.7
# 4  nissan  white         213095      4   350000    5.0            9.3
# 5  toyota  green          99213      4   450000    6.0            2.1
# 6   honda   blue          45698      4   750000    6.0            3.0
# 7   honda   blue          54738      4   700000    6.0            8.0
# 8  toyota  white          60000      4   625000    6.0            5.0
# 9  nissan  white          31600      4   970000    6.0            8.0
#
#    Total fuel used(L)  Number of wheels  Passed for saftey   Types
# 0           11253.225                 4               True  Dissel
# ...

# %%
#Frace is fraction of sample its gonna be only integer form
car_sales_shuffled=car_sales.sample(frac=1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  fuel per 100k  \
# 1   honda    red          87899      4   500000    5.0            5.6
# 0  toyota  white         150043      4   400000    5.0            7.5
# 8  toyota  white          60000      4   625000    6.0            5.0
# 5  toyota  green          99213      4   450000    6.0            2.1
# 3     bmw  black          11179      5  2200000    5.0            6.7
# 4  nissan  white         213095      4   350000    5.0            9.3
# 6   honda   blue          45698      4   750000    6.0            3.0
# 9  nissan  white          31600      4   970000    6.0            8.0
# 2  toyota   blue          32549      3   700000    5.0            8.5
# 7   honda   blue          54738      4   700000    6.0            8.0
#
#    Total fuel used(L)  Number of wheels  Passed for saftey   Types
# 1            4922.344                 4               True  Petrol
# ...

# %%
#Only select 20% percent of data 
#for example we have like 2 million rows then we take like 0.01
#first we have to take small amount of data and do litle experiment and upgrade those experiment as you figure what works.
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  fuel per 100k  \
# 1   honda    Red          87899      4  500000    5.0            5.6
# 8  toyota  White          60000      4  625000    5.0            5.0
#
#    Number of wheel  Passed for saftey  Total fuel used(L)  fluids   Types
# 1                4               True            4922.344  Petrol  Petrol
# 8                4               True            3000.000  Dissel  Dissel

# %%
car_sales_shuffled.reset_index()
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  fuel per 100k  \
# 1   honda    red          87899      4   500000    5.0            5.6
# 0  toyota  white         150043      4   400000    5.0            7.5
# 8  toyota  white          60000      4   625000    6.0            5.0
# 5  toyota  green          99213      4   450000    6.0            2.1
# 3     bmw  black          11179      5  2200000    5.0            6.7
# 4  nissan  white         213095      4   350000    5.0            9.3
# 6   honda   blue          45698      4   750000    6.0            3.0
# 9  nissan  white          31600      4   970000    6.0            8.0
# 2  toyota   blue          32549      3   700000    5.0            8.5
# 7   honda   blue          54738      4   700000    6.0            8.0
#
#    Total fuel used(L)  Number of wheels  Passed for saftey   Types
# 1            4922.344                 4               True  Petrol
# ...

# %%
#covert km to miles number is 1.603
car_sales["Odometer (KM)"]=car_sales["Odometer (KM)"].apply(lambda x: x /1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  fuel per 100k  \
# 0  toyota  white   58610.546875      4   400000    5.0            7.5
# 1   honda    red   34335.546875      4   500000    5.0            5.6
# 2  toyota   blue   12714.453125      3   700000    5.0            8.5
# 3     bmw  black    4366.796875      5  2200000    5.0            6.7
# 4  nissan  white   83240.234375      4   350000    5.0            9.3
# 5  toyota  green   38755.078125      4   450000    6.0            2.1
# 6   honda   blue   17850.781250      4   750000    6.0            3.0
# 7   honda   blue   21382.031250      4   700000    6.0            8.0
# 8  toyota  white   23437.500000      4   625000    6.0            5.0
# 9  nissan  white   12343.750000      4   970000    6.0            8.0
#
#    Total fuel used(L)  Number of wheels  Passed for saftey   Types
# 0           11253.225                 4               True  Dissel
# ...

# %%
#Try it,run your code
#Search for it
#Try again
#Ask
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  fuel per 100k  \
# 0  toyota  white   58610.546875      4   400000    5.0            7.5
# 1   honda    red   34335.546875      4   500000    5.0            5.6
# 2  toyota   blue   12714.453125      3   700000    5.0            8.5
# 3     bmw  black    4366.796875      5  2200000    5.0            6.7
# 4  nissan  white   83240.234375      4   350000    5.0            9.3
# 5  toyota  green   38755.078125      4   450000    6.0            2.1
# 6   honda   blue   17850.781250      4   750000    6.0            3.0
# 7   honda   blue   21382.031250      4   700000    6.0            8.0
# 8  toyota  white   23437.500000      4   625000    6.0            5.0
# 9  nissan  white   12343.750000      4   970000    6.0            8.0
#
#    Total fuel used(L)  Number of wheels  Passed for saftey   Types
# 0           11253.225                 4               True  Dissel
# ...
